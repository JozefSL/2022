# %% [markdown]
# <a href="https://colab.research.google.com/github/JozefSL/2022/blob/main/eia/wklyStats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import pandas as pd
#import pyodbc
import requests
from IPython.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))
import plotly.express as px
import os
import certifi
# Out:
# <style>.container { width:98% !important; }</style>

# %%
os.environ['REQUESTS_CA_BUNDLE'] = certifi.where()

# %%
api_key = "A693B616B2FBE916015651E6F7F947E1"

# %%
eiaLogo = "https://upload.wikimedia.org/wikipedia/commons/1/1f/Energy_Information_Administration_logo.svg"
eiaLg = [dict(source = eiaLogo,
                       x=1.07, y=-0.1,
                       sizex=0.15, sizey=0.15,
                       xanchor="center", yanchor="bottom")]
eiaLg2 = [dict(source = eiaLogo,
                        x=1.03, y=1.1,
                        sizex=0.1, sizey=0.1,
                        xanchor="center", yanchor="bottom")]

# %%
url = 'https://api.eia.gov/v2/petroleum/stoc/wstk/data/?api_key='+ api_key + '&data[0]=value&frequency=weekly&start=2000-08-01&sort[0][column]=period&sort[0][direction]=asc&facets[series][]='

# %%
dataKeys =  ['WCESTUS1',
             'WCRSTUS1',
             'WG4ST_NUS_1']

# %%
pData = pd.DataFrame()

for key in dataKeys:
    response = requests.get(url + key)    #request data
    df = pd.DataFrame(response.json().get('response').get('data'))[['period','value']]
    df.columns = ['Period', key]
    df = df.set_index('Period')

    print(key)
    if pData.empty:
        pData = df
    else:
        pData = pData.join(df)

#pData *= 1000000
# Out:
# WCESTUS1
# WCRSTUS1
# WG4ST_NUS_1

# %%
pData
# Out:
#            WCESTUS1 WCRSTUS1 WG4ST_NUS_1
# Period
# 2000-08-04   269659   840011      121669
# 2000-08-11   273059   843925      119748
# 2000-08-18   268901   839767      117095
# 2000-08-25   270948   842054      114765
# 2000-09-01   273691   844797      112969
# ...             ...      ...         ...
# 2024-08-30   418310   797982       15403
# 2024-09-06   419143   799094       15495
# 2024-09-13   417513   798119       16908
# 2024-09-20   413042   794935       15656
# 2024-09-27   416931   799484       17108
#
# [1261 rows x 3 columns]
